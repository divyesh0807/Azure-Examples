# %% [markdown]
# # Resources
# https://learn.microsoft.com/en-us/azure/ai-services/speech-service/quickstarts/setup-platform?pivots=programming-language-python&tabs=windows%2Cubuntu%2Cdotnetcli%2Cdotnet%2Cjre%2Cmaven%2Cnodejs%2Cmac%2Cpypi
# https://github.com/Azure-Samples/cognitive-services-speech-sdk/tree/master/samples/python/console

# %%
# %pip install azure-cognitiveservices-speech
# Out:
# Collecting azure-cognitiveservices-speech
#   Downloading azure_cognitiveservices_speech-1.50.0-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: azure-core>=1.33.0 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from azure-cognitiveservices-speech) (1.37.0)
# Requirement already satisfied: requests>=2.21.0 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from azure-core>=1.33.0->azure-cognitiveservices-speech) (2.32.5)
# Requirement already satisfied: typing-extensions>=4.6.0 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from azure-core>=1.33.0->azure-cognitiveservices-speech) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from requests>=2.21.0->azure-core>=1.33.0->azure-cognitiveservices-speech) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from requests>=2.21.0->azure-core>=1.33.0->azure-cognitiveservices-speech) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from requests>=2.21.0->azure-core>=1.33.0->azure-cognitiveservices-speech) (2.6.2)
# Requirement already satisfied: certifi>=2017.4.17 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from requests>=2.21.0->azure-core>=1.33.0->azure-cognitiveservices-speech) (2026.1.4)
# Downloading azure_cognitiveservices_speech-1.50.0-py3-none-manylinux1_x86_64.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 19.8 MB/s  0:00:00
# Installing collected packages: azure-cognitiveservices-speech
# Successfully installed azure-cognitiveservices-speech-1.50.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import azure.cognitiveservices.speech as speechsdk

# %%
apikey = "######"
endpoint = "#########"
region = 'eastus2'

# %%
speech_config = speechsdk.SpeechConfig(subscription=apikey, region=region)
# audio_config = speechsdk.audio.AudioOutputConfig(use_default_speaker=True)

# %%
speech_config.speech_synthesis_voice_name='en-US-AvaMultilingualNeural'

# %%
speech_synthesizer = speechsdk.SpeechSynthesizer(speech_config=speech_config, audio_config=None)

# %%
text = "well done, your doing good job almost there.. keep going"

# %%
results = speech_synthesizer.speak_text_async(text).get()

# %%
output_file = "output.wav"

if results.reason == speechsdk.ResultReason.SynthesizingAudioCompleted:
    print("Speech synthesized for text [{}]".format(text))
    stream = speechsdk.AudioDataStream(results)
    stream.save_to_wav_file(output_file)
    print(f"Audio saved to {output_file}")    
elif results.reason == speechsdk.ResultReason.Canceled:
    print("Speech synthesis canceled: {}".format(cancellation_details.reason))
    if cancellation_details.reason == speechsdk.CancellationReason.Error:
        if cancellation_details.error_details:
            print("Error details: {}".format(cancellation_details.error_details))
            print("Did you set the speech resource key and region values?")
# Out:
# Speech synthesized for text [well done, your doing good job almost there.. keep going]
# Audio saved to output.wav

# %%
print(results)
# Out:
# SpeechSynthesisResult(result_id=22ae504802d54e01ad0c3867a7d5a1c0, reason=ResultReason.SynthesizingAudioCompleted, audio_length=140446)
